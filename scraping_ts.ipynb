# %% [markdown]
# # Scraping Booking for Primavera Sound

# %%
# Core imports
import pandas as pd
import numpy as np
import requests
import time
import random
import re
from datetime import datetime, timedelta

# Selenium imports
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import (
    TimeoutException, 
    NoSuchElementException,
    StaleElementReferenceException
)

# For automatic chromedriver management
from webdriver_manager.chrome import ChromeDriverManager

# For parsing HTML
from bs4 import BeautifulSoup

# Suppress warnings
import warnings
warnings.filterwarnings('ignore')

# import datetime
from datetime import datetime, timedelta
import os

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Open the Booking.com in workable condition

# %%
def open_website(website_url, headless_bool=False):
    # Create a simple driver (WITH visible browser window)
    options = Options()

    if headless_bool:
        options.add_argument("--headless=new")

    options.add_argument("--no-sandbox")
    options.add_argument("--disable-dev-shm-usage")
    options.add_argument("--incognito")

    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)

    print("✅ Browser opened!")
    time.sleep(3)  # Wait for page to load

    driver.get(website_url)
    time.sleep(3)  # Wait for page to load

    print("✅ Navigated to Booking.com search results")
    print(f"Page title: {driver.title}")

    driver.set_window_size(1400, 900)

    # accept cookies
    accept_button = driver.find_element(By.ID, "onetrust-accept-btn-handler")
    accept_button.click()  # Example: Accept cookies button
    time.sleep(5)  # Wait for page to load

    
    wait = WebDriverWait(driver, 10)

    close_signin = wait.until(
        EC.element_to_be_clickable(
            (By.CSS_SELECTOR, "button[aria-label='Dismiss sign-in info.']")
        )
    )
    close_signin.click()
    
    return driver

# %% [markdown]
# ## Search the chosen city and dates

# %%
def search(driver, city, start_date, end_date):

    wait = WebDriverWait(driver, 10)

    # type in selected city
    city_input = driver.find_element(By.NAME, "ss")
    city_input.send_keys(city)
    time.sleep(2)

    js = """
    document.addEventListener("mousemove", e => {
        const box = document.getElementById("__coords__") || (() => {
            const d = document.createElement("div");
            d.id = "__coords__";
            d.style.cssText = `
                position:fixed;top:0;left:0;z-index:999999;
                background:black;color:lime;
                font:12px monospace;padding:4px;
                pointer-events:none;
            `;
            document.body.appendChild(d);
            return d;
        })();

        box.textContent = `x:${e.clientX} y:${e.clientY}`;
    });
    """

    driver.execute_script(js)

    # select the city
    x = 250
    y = 420
    driver.execute_script(f"document.elementFromPoint({x}, {y}).click();")
    time.sleep(2)

    # scroll to necessary month
    next_btn = wait.until(
        EC.element_to_be_clickable((By.CSS_SELECTOR, "button[aria-label='Next month']"))
    )

    start = datetime.strptime(start_date, "%Y-%m-%d")
    today = datetime.today()
    months = (start.year - today.year) * 12 + (start.month - today.month)

    for _ in range(months):
        time.sleep(1)
        next_btn.click()

    # select dates
    wait.until(
        EC.element_to_be_clickable((By.CSS_SELECTOR, f"span[data-date='{start_date}']"))
    ).click()

    time.sleep(2)
    
    wait.until(
        EC.element_to_be_clickable((By.CSS_SELECTOR, f"span[data-date='{end_date}']"))
    ).click()

    # click search
    for span in driver.find_elements(By.TAG_NAME, "span"):
        if span.text.strip().lower() == "search":
            span.click()
            break
    
    print("✅ Search Complete")    
    return driver

# %% [markdown]
# ## Get the full list of listing

# %%
def collect_all_hotels(driver):
    driver.execute_script("window.scrollTo(0, 0);")
    time.sleep(2)
    
    hotel_data = {}  # Use dict to avoid duplicates by link
    last_count = 0
    stagnation = 0
    MAX_STAGNATION = 15
    SCROLL_STEP = 900
    SCROLL_PAUSE = 3
    
    print("Starting scrolling ...")
    
    while True:
        # Scroll
        driver.execute_script(f"window.scrollBy(0, {SCROLL_STEP});")
        time.sleep(SCROLL_PAUSE)
        
        # Click "Load more"
        try:
            btn = driver.find_element(By.XPATH, "//span[text()='Load more results']")
            driver.execute_script("arguments[0].scrollIntoView({block:'center'});", btn)
            time.sleep(2)
            btn.click()
            time.sleep(2)
        except:
            pass
        
        # Collect hotels
        cards = driver.find_elements(By.CSS_SELECTOR, "div[data-testid='property-card']")
        for card in cards:
            try:
                # Extract link
                link = card.find_element(By.CSS_SELECTOR, "a[data-testid='property-card-desktop-single-image']").get_attribute("href")
                
                if not link or link in hotel_data:
                    continue
                
                # Extract title
                try:
                    title = card.find_element(By.CSS_SELECTOR, "div[data-testid='title']").text
                except:
                    title = None
                
                # Extract price
                try:
                    price = card.find_element(
                        By.CSS_SELECTOR, "span[data-testid='price-and-discounted-price']"
                    ).text
                except:
                    price = None
                
                # Store data
                hotel_data[link] = {'link': link, 'hotel': title, 'price': price}
                
            except:
                continue
        
        current = len(hotel_data)
        print(f"Unique hotels: {current}")
        
        # Stop condition (data-based)
        if current == last_count:
            stagnation += 1
            print(f"No growth ({stagnation}/{MAX_STAGNATION})")
        else:
            stagnation = 0
        
        last_count = current
        
        if stagnation >= MAX_STAGNATION:
            print("No more hotels loading — confirmed.")
            break
    
    print(f"FINAL HOTEL COUNT: {len(hotel_data)}")
    
    # Convert to DataFrame
    df = pd.DataFrame.from_dict(hotel_data, orient='index')
    df = df.reset_index(drop=True)
    
    return driver, df

# %% [markdown]
# ## extract description

# %%
def extract_description(driver, link):
    # Navigate to the link
    driver.get(link)

    # Maximize the window to make sure it's visible
    driver.maximize_window()

    # Wait for page to load
    time.sleep(1)

    # Bring window to front (different methods for different OS)
    try:
        driver.switch_to.window(driver.current_window_handle)
    except:
        pass

    # Verify we're on the right page
    print(f"Navigating to: {driver.title}")

    # Extract the description
    try:
        description = driver.find_element(By.CSS_SELECTOR, "p[data-testid='property-description']").text
        print("Description extracted\n")    
    except Exception as e:
        print(f"Error extracting description: {e}")
        description = None
    return description

# %% [markdown]
# ## Run the process flow

# %%
booking_url = "https://www.booking.com/?lang=en-us&selected_currency=EUR"

# Loop start and end dates
current_date = datetime.strptime("2026-03-13", "%Y-%m-%d")
end_loop_date = datetime.strptime("2026-03-15", "%Y-%m-%d")

# Select city
city = "Valencia"
output_dir = f"data/{city}"
os.makedirs(output_dir, exist_ok=True)

while current_date <= end_loop_date:

    start_date_str = current_date.strftime("%Y-%m-%d")
    end_date_str = (current_date + timedelta(days=7)).strftime("%Y-%m-%d")

    print(f"Scraping {start_date_str} → {end_date_str}\n")

    # Open website
    driver = open_website(website_url=booking_url)

    # Search for Valencia with the given dates
    driver = search(driver=driver, city=city, start_date=start_date_str, end_date=end_date_str)

    # Collect hotels
    driver, hotels_df = collect_all_hotels(driver)
    print("✅ Collecting Hotels ended")

    # Loop through all the hotels
    n = len(hotels_df)  

    # Create 'text' column 
    hotels_df['text'] = None

    for i in range(n):
        link = hotels_df.loc[i, 'link']
        title = hotels_df.loc[i, 'hotel']
        
        print(f"Extracting Description for {i+1}/{n}: {title} ")
        
        # Extract description
        description = extract_description(driver, link)

        # Store in DataFrame
        hotels_df.at[i, 'text'] = description
        
        # Sleep for seconds after each round
        time.sleep(random.randint(1, 4))

    print(f"✅ Completed extracting descriptions for {min(n, len(hotels_df))} hotels")

    # Save output
    save_path = os.path.join(output_dir, f"{start_date_str}.csv")
    hotels_df.to_csv(save_path, index=False)

    print(f"✅ Saved: {save_path}")

    time.sleep(60)

    # Move to next day
    current_date += timedelta(days=1)
# Out:
# Scraping 2026-03-13 → 2026-03-20
#
# ✅ Browser opened!
# ✅ Navigated to Booking.com search results
# Page title: Booking.com | Official site | The best hotels, flights, car rentals & accommodations
# ✅ Search Complete
# Starting scrolling ...
# Unique hotels: 25
# Unique hotels: 25
# No growth (1/15)
# Unique hotels: 25
# No growth (2/15)
# Unique hotels: 25
# No growth (3/15)
# Unique hotels: 25
# No growth (4/15)
# Unique hotels: 25
# No growth (5/15)
# Unique hotels: 75
# Unique hotels: 75
# No growth (1/15)
# Unique hotels: 75
# No growth (2/15)
# Unique hotels: 75
# No growth (3/15)
# Unique hotels: 75
# No growth (4/15)
# Unique hotels: 75
# No growth (5/15)
# Unique hotels: 75
# No growth (6/15)
# Unique hotels: 75
# No growth (7/15)
# Unique hotels: 150
# Unique hotels: 200
# Unique hotels: 248
# Unique hotels: 297
# Unique hotels: 345
# Unique hotels: 395
# Unique hotels: 442
# Unique hotels: 476
# Unique hotels: 513
# Unique hotels: 550
# Unique hotels: 590
# Unique hotels: 636
# Unique hotels: 685
# Unique hotels: 734
# Unique hotels: 784
# Unique hotels: 834
# Unique hotels: 884
# Unique hotels: 934
# Unique hotels: 984
# Unique hotels: 1034
# Unique hotels: 1084
# Unique hotels: 1134
# Unique hotels: 1184
# Unique hotels: 1234
# Unique hotels: 1284
# Unique hotels: 1334
# Unique hotels: 1384
# Unique hotels: 1434
# Unique hotels: 1484
# Unique hotels: 1534
# Unique hotels: 1575
# Unique hotels: 1575
# No growth (1/15)
# Unique hotels: 1575
# No growth (2/15)
# Unique hotels: 1575
# No growth (3/15)
# Unique hotels: 1575
# No growth (4/15)
# Unique hotels: 1575
# No growth (5/15)
# Unique hotels: 1575
# No growth (6/15)
# Unique hotels: 1575
# No growth (7/15)
# Unique hotels: 1575
# No growth (8/15)
# Unique hotels: 1575
# No growth (9/15)
# Unique hotels: 1575
# No growth (10/15)
# Unique hotels: 1575
# No growth (11/15)
# Unique hotels: 1575
# No growth (12/15)
# Unique hotels: 1575
# No growth (13/15)
# Unique hotels: 1575
# No growth (14/15)
# Unique hotels: 1575
# No growth (15/15)
# No more hotels loading — confirmed.
# FINAL HOTEL COUNT: 1575
# ✅ Collecting Hotels ended
# Extracting Description for 1/1575: VLC HOST - Reina 168
# Navigating to: VLC HOST - Reina 168, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 2/1575: Hospederia del Pilar
# Navigating to: Hospederia del Pilar, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 3/1575: VLC HOST - Zapadores
# Navigating to: VLC HOST - Zapadores, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 4/1575: Sorolla Urban Suites
# Navigating to: Sorolla Urban Suites, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 5/1575: Hotel Medium Valencia
# Navigating to: Hotel Medium Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 6/1575: San Miguel, Luxury apartments.
# Navigating to: San Miguel, Luxury apartments., Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 7/1575: Las Arenas Balneario Resort
# Navigating to: Las Arenas Balneario Resort, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 8/1575: Melia Valencia
# Navigating to: Melia Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 9/1575: Hotel Pathos by Mimood Aparthotels
# Navigating to: Hotel Pathos by Mimood Aparthotels, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 10/1575: Senator Parque Central
# Navigating to: Senator Parque Central, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 11/1575: Kora Lluna
# Navigating to: Kora Lluna, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 12/1575: Exe Rey Don Jaime
# Navigating to: Exe Rey Don Jaime, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 13/1575: DWO Valencia
# Navigating to: DWO Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 14/1575: BET Apartments - Suites Puerto Valencia
# Navigating to: BET Apartments - Suites Puerto Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 15/1575: Hostal RR Feria by Beleret
# Navigating to: Hostal RR Feria by Beleret, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 16/1575: Apartamento Ciudad de Las Ciencias - Apartamento Ciudad de Les Arts
# Navigating to: Apartamento Ciudad de Las Ciencias - Apartamento Ciudad de Les Arts, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 17/1575: BET Apartments - Reig
# Navigating to: BET Apartments - Reig, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 18/1575: BET Apartments - Abastos
# Navigating to: BET Apartments - Abastos, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 19/1575: Macflats Valencia Puerto
# Navigating to: Macflats Valencia Puerto, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 20/1575: Reinapart Valencia Beach
# Navigating to: Reinapart Valencia Beach, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 21/1575: SOHO BY THE SEA Valencia
# Navigating to: SOHO BY THE SEA Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 22/1575: El Globo
# Navigating to: El Globo, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 23/1575: Hotel Miramar Valencia
# Navigating to: Hotel Miramar Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 24/1575: SingularStays Valencia Center
# Navigating to: SingularStays Valencia Center, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 25/1575: Living Valencia Apartments - Merced
# Navigating to: Living Valencia Apartments - Merced, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 26/1575: VLC HOST - Reina 168
# Navigating to: VLC HOST - Reina 168, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 27/1575: Hospederia del Pilar
# Navigating to: Hospederia del Pilar, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 28/1575: VLC HOST - Zapadores
# Navigating to: VLC HOST - Zapadores, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 29/1575: Sorolla Urban Suites
# Navigating to: Sorolla Urban Suites, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 30/1575: Hotel Medium Valencia
# Navigating to: Hotel Medium Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 31/1575: San Miguel, Luxury apartments.
# Navigating to: San Miguel, Luxury apartments., Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 32/1575: Las Arenas Balneario Resort
# Navigating to: Las Arenas Balneario Resort, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 33/1575: Melia Valencia
# Navigating to: Melia Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 34/1575: Hotel Pathos by Mimood Aparthotels
# Navigating to: Hotel Pathos by Mimood Aparthotels, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 35/1575: Senator Parque Central
# Navigating to: Senator Parque Central, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 36/1575: Kora Lluna
# Navigating to: Kora Lluna, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 37/1575: Exe Rey Don Jaime
# Navigating to: Exe Rey Don Jaime, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 38/1575: DWO Valencia
# Navigating to: DWO Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 39/1575: BET Apartments - Suites Puerto Valencia
# Navigating to: BET Apartments - Suites Puerto Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 40/1575: Hostal RR Feria by Beleret
# Navigating to: Hostal RR Feria by Beleret, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 41/1575: Apartamento Ciudad de Las Ciencias - Apartamento Ciudad de Les Arts
# Navigating to: Apartamento Ciudad de Las Ciencias - Apartamento Ciudad de Les Arts, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 42/1575: BET Apartments - Reig
# Navigating to: BET Apartments - Reig, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 43/1575: BET Apartments - Abastos
# Navigating to: BET Apartments - Abastos, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 44/1575: Macflats Valencia Puerto
# Navigating to: Macflats Valencia Puerto, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 45/1575: Reinapart Valencia Beach
# Navigating to: Reinapart Valencia Beach, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 46/1575: SOHO BY THE SEA Valencia
# Navigating to: SOHO BY THE SEA Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 47/1575: El Globo
# Navigating to: El Globo, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 48/1575: Hotel Miramar Valencia
# Navigating to: Hotel Miramar Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 49/1575: SingularStays Valencia Center
# Navigating to: SingularStays Valencia Center, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 50/1575: Living Valencia Apartments - Merced
# Navigating to: Living Valencia Apartments - Merced, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 51/1575: FLORIT FLATS - Trafalgar Arts & Port Suites
# Navigating to: FLORIT FLATS - Trafalgar Arts & Port Suites, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 52/1575: NH Valencia Las Artes
# Navigating to: NH Valencia Las Artes, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 53/1575: Malvarrosa Beach Stay!
# Navigating to: Malvarrosa Beach Stay!, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 54/1575: Bet Apartments - Sunrise Beach Apartments
# Navigating to: Bet Apartments - Sunrise Beach Apartments, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 55/1575: Hotel Dimar
# Navigating to: Hotel Dimar, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 56/1575: Eurostars Acteón
# Navigating to: Eurostars Acteón, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 57/1575: Hotel RH Sorolla Centro
# Navigating to: Hotel RH Sorolla Centro, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 58/1575: NH Valencia Las Ciencias
# Navigating to: NH Valencia Las Ciencias, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 59/1575: Precioso apartamento con patio. PYP
# Navigating to: Precioso apartamento con patio. PYP, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 60/1575: Hotel Valencia Center
# Navigating to: Hotel Valencia Center, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 61/1575: Primus Valencia
# Navigating to: Primus Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 62/1575: A123 ViviendaTuristicaValencia Grandes Grupos
# Navigating to: A123 ViviendaTuristicaValencia Grandes Grupos, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 63/1575: The White Apartment: Luxury, Beach and Design
# Navigating to: The White Apartment: Luxury, Beach and Design, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 64/1575: NH Valencia Center
# Navigating to: NH Valencia Center, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 65/1575: iStay by NH Ciudad de Valencia Hotel
# Navigating to: iStay by NH Ciudad de Valencia Hotel, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 66/1575: Resa Patacona
# Navigating to: Resa Patacona, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 67/1575: Apartamentos Core Suites Valencia
# Navigating to: Apartamentos Core Suites Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 68/1575: B&B HOTEL Valencia Arena
# Navigating to: B&B HOTEL Valencia Arena, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 69/1575: El Coso
# Navigating to: El Coso, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 70/1575: Valdeolivas Suites
# Navigating to: Valdeolivas Suites, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 71/1575: Barceló Valencia
# Navigating to: Barceló Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 72/1575: Sercotel Sorolla Palace
# Navigating to: Sercotel Sorolla Palace, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 73/1575: Arena Zone Hotel
# Navigating to: Arena Zone Hotel, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 74/1575: ESTIMAR Valencia
# Navigating to: ESTIMAR Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 75/1575: SH Valencia Palace
# Navigating to: SH Valencia Palace, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 76/1575: VLC HOST - Reina 168
# Navigating to: VLC HOST - Reina 168, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 77/1575: Hospederia del Pilar
# Navigating to: Hospederia del Pilar, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 78/1575: VLC HOST - Zapadores
# Navigating to: VLC HOST - Zapadores, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 79/1575: Sorolla Urban Suites
# Navigating to: Sorolla Urban Suites, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 80/1575: Hotel Medium Valencia
# Navigating to: Hotel Medium Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 81/1575: San Miguel, Luxury apartments.
# Navigating to: San Miguel, Luxury apartments., Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 82/1575: Las Arenas Balneario Resort
# Navigating to: Las Arenas Balneario Resort, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 83/1575: Melia Valencia
# Navigating to: Melia Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 84/1575: Hotel Pathos by Mimood Aparthotels
# Navigating to: Hotel Pathos by Mimood Aparthotels, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 85/1575: Senator Parque Central
# Navigating to: Senator Parque Central, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 86/1575: Kora Lluna
# Navigating to: Kora Lluna, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 87/1575: Exe Rey Don Jaime
# Navigating to: Exe Rey Don Jaime, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 88/1575: DWO Valencia
# Navigating to: DWO Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 89/1575: BET Apartments - Suites Puerto Valencia
# Navigating to: BET Apartments - Suites Puerto Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 90/1575: Hostal RR Feria by Beleret
# Navigating to: Hostal RR Feria by Beleret, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 91/1575: Apartamento Ciudad de Las Ciencias - Apartamento Ciudad de Les Arts
# Navigating to: Apartamento Ciudad de Las Ciencias - Apartamento Ciudad de Les Arts, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 92/1575: BET Apartments - Reig
# Navigating to: BET Apartments - Reig, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 93/1575: BET Apartments - Abastos
# Navigating to: BET Apartments - Abastos, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 94/1575: Macflats Valencia Puerto
# Navigating to: Macflats Valencia Puerto, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 95/1575: Reinapart Valencia Beach
# Navigating to: Reinapart Valencia Beach, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 96/1575: SOHO BY THE SEA Valencia
# Navigating to: SOHO BY THE SEA Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 97/1575: El Globo
# Navigating to: El Globo, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 98/1575: Hotel Miramar Valencia
# Navigating to: Hotel Miramar Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 99/1575: SingularStays Valencia Center
# Navigating to: SingularStays Valencia Center, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 100/1575: Living Valencia Apartments - Merced
# Navigating to: Living Valencia Apartments - Merced, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 101/1575: RM1 - Loft Valencia cómodos estudios dúplex cerca a la Avenida del Puerto
# Navigating to: RM1 - Loft Valencia cómodos estudios dúplex cerca a la Avenida del Puerto, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 102/1575: Filologo Sanelo Luxury Apartaments
# Navigating to: Filologo Sanelo Luxury Apartaments, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 103/1575: Eurostars Gran Valencia
# Navigating to: Eurostars Gran Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 104/1575: The Little Corner B&B
# Navigating to: The Little Corner B&B, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 105/1575: Palau Suites & Apartments
# Navigating to: Palau Suites & Apartments, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 106/1575: COOL LOFTS center valencia
# Navigating to: COOL LOFTS center valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 107/1575: Hotel Boutique Sabbia Valencia
# Navigating to: Hotel Boutique Sabbia Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 108/1575: Hotel Malcom and Barret
# Navigating to: Hotel Malcom and Barret, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 109/1575: Soho Boutique Turia
# Navigating to: Soho Boutique Turia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 110/1575: Maison Primado B&B
# Navigating to: Maison Primado B&B, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 111/1575: INNSiDE by Melia Valencia Oceanic
# Navigating to: INNSiDE by Melia Valencia Oceanic, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 112/1575: PTZ 1B - Loft Valencia
# Navigating to: PTZ 1B - Loft Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 113/1575: Blanq Carmen Hotel
# Navigating to: Blanq Carmen Hotel, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 114/1575: Calixto Delight
# Navigating to: Calixto Delight, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 115/1575: IF - Loft Valencia estudios encantadores y bien conectados en zona residencial Malilla
# Navigating to: IF - Loft Valencia estudios encantadores y bien conectados en zona residencial Malilla, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 116/1575: Travel Habitat Mediterranean Suites
# Navigating to: Travel Habitat Mediterranean Suites, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 117/1575: City of Arts Valencia Flats by Rent Me
# Navigating to: City of Arts Valencia Flats by Rent Me, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 118/1575: ESC - Loft Valencia Cómodos y espaciosos estudios cercanos a estación Joaquín Sorolla
# Navigating to: ESC - Loft Valencia Cómodos y espaciosos estudios cercanos a estación Joaquín Sorolla, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 119/1575: Travel Habitat Zaidia con Terraza
# Navigating to: Travel Habitat Zaidia con Terraza, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 120/1575: Ilunion Aqua 4
# Navigating to: Ilunion Aqua 4, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 121/1575: Hotel Boutique Balandret
# Navigating to: Hotel Boutique Balandret, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 122/1575: VLC HOST - Cubells
# Navigating to: VLC HOST - Cubells, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 123/1575: Welcomer Apartments Valencia
# Navigating to: Welcomer Apartments Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 124/1575: Nest Style Valencia
# Navigating to: Nest Style Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 125/1575: PPA22 Loft Valencia - Acogedor loft cercano al metro Zona Ayora
# Navigating to: PPA22 Loft Valencia - Acogedor loft cercano al metro Zona Ayora, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 126/1575: Flats Friends Tetuan
# Navigating to: Flats Friends Tetuan, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 127/1575: Ilunion Valencia 3
# Navigating to: Ilunion Valencia 3, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 128/1575: Hotel Olympia Universidades
# Navigating to: Hotel Olympia Universidades, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 129/1575: Travel Habitat La Marina Real
# Navigating to: Travel Habitat La Marina Real, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 130/1575: Hotel Mediterraneo Valencia
# Navigating to: Hotel Mediterraneo Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 131/1575: Hotel Nido Malvarrosa
# Navigating to: Hotel Nido Malvarrosa, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 132/1575: Hotel Turia Valencia
# Navigating to: Hotel Turia Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 133/1575: Ilunion Valencia 4
# Navigating to: Ilunion Valencia 4, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 134/1575: Loft a 5min de la playa
# Navigating to: Loft a 5min de la playa, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 135/1575: Petit Palace Plaza de la Reina
# Navigating to: Petit Palace Plaza de la Reina, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 136/1575: Axel Hotel Valencia - Adults Only
# Navigating to: Axel Hotel Valencia - Adults Only, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 137/1575: Pensión Moratin
# Navigating to: Pensión Moratin, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 138/1575: GuestReady - A lovely studio in la Saidia Valencia
# Navigating to: GuestReady - A lovely studio in la Saidia Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 139/1575: Vincci Palace
# Navigating to: Vincci Palace, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 140/1575: Zenit Valencia
# Navigating to: Zenit Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 141/1575: SH Colón Valencia
# Navigating to: SH Colón Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 142/1575: FLORIT FLATS - The Patraix Apartments
# Navigating to: FLORIT FLATS - The Patraix Apartments, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 143/1575: FLORIT FLATS - CENTER Luxurious 1BR 1BA Terrace WI-FI AC
# Navigating to: FLORIT FLATS - CENTER Luxurious 1BR 1BA Terrace WI-FI AC, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 144/1575: Reinapart Patacona Beachfront Seaview
# Navigating to: Reinapart Patacona Beachfront Seaview, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 145/1575: Hospes Palau de La Mar, Valencia, a Member of Design Hotels
# Navigating to: Hospes Palau de La Mar, Valencia, a Member of Design Hotels, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 146/1575: Sercotel Valencia Alameda 41
# Navigating to: Sercotel Valencia Alameda 41, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 147/1575: Petit Palace Ruzafa
# Navigating to: Petit Palace Ruzafa, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 148/1575: Saman Hotel Boutique
# Navigating to: Saman Hotel Boutique, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 149/1575: Opera House Valencia B&B
# Navigating to: Opera House Valencia B&B, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 150/1575: GuestReady - Llovera apartments
# Navigating to: GuestReady - Llovera apartments, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 151/1575: VLC HOST - Reina 168
# Navigating to: VLC HOST - Reina 168, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 152/1575: Hospederia del Pilar
# Navigating to: Hospederia del Pilar, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 153/1575: VLC HOST - Zapadores
# Navigating to: VLC HOST - Zapadores, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 154/1575: Sorolla Urban Suites
# Navigating to: Sorolla Urban Suites, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 155/1575: Hotel Medium Valencia
# Navigating to: Hotel Medium Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 156/1575: San Miguel, Luxury apartments.
# Navigating to: San Miguel, Luxury apartments., Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 157/1575: Las Arenas Balneario Resort
# Navigating to: Las Arenas Balneario Resort, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 158/1575: Melia Valencia
# Navigating to: Melia Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 159/1575: Hotel Pathos by Mimood Aparthotels
# Navigating to: Hotel Pathos by Mimood Aparthotels, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 160/1575: Senator Parque Central
# Navigating to: Senator Parque Central, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 161/1575: Kora Lluna
# Navigating to: Kora Lluna, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 162/1575: Exe Rey Don Jaime
# Navigating to: Exe Rey Don Jaime, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 163/1575: DWO Valencia
# Navigating to: DWO Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 164/1575: BET Apartments - Suites Puerto Valencia
# Navigating to: BET Apartments - Suites Puerto Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 165/1575: Hostal RR Feria by Beleret
# Navigating to: Hostal RR Feria by Beleret, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 166/1575: Apartamento Ciudad de Las Ciencias - Apartamento Ciudad de Les Arts
# Navigating to: Apartamento Ciudad de Las Ciencias - Apartamento Ciudad de Les Arts, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 167/1575: BET Apartments - Reig
# Navigating to: BET Apartments - Reig, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 168/1575: BET Apartments - Abastos
# Navigating to: BET Apartments - Abastos, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 169/1575: Macflats Valencia Puerto
# Navigating to: Macflats Valencia Puerto, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 170/1575: Reinapart Valencia Beach
# Navigating to: Reinapart Valencia Beach, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 171/1575: SOHO BY THE SEA Valencia
# Navigating to: SOHO BY THE SEA Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 172/1575: El Globo
# Navigating to: El Globo, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 173/1575: Hotel Miramar Valencia
# Navigating to: Hotel Miramar Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 174/1575: SingularStays Valencia Center
# Navigating to: SingularStays Valencia Center, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 175/1575: Living Valencia Apartments - Merced
# Navigating to: Living Valencia Apartments - Merced, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 176/1575: COOL LOFTS ALAMEDA VALENCIA
# Navigating to: COOL LOFTS ALAMEDA VALENCIA, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 177/1575: B48 Valencia Feria
# Navigating to: B48 Valencia Feria, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 178/1575: Vincci Lys
# Navigating to: Vincci Lys, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 179/1575: Housing Maritim by SharingCo
# Navigating to: Housing Maritim by SharingCo, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 180/1575: Osito Hub - Colomer
# Navigating to: Osito Hub - Colomer, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 181/1575: Vincci Mercat
# Navigating to: Vincci Mercat, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 182/1575: Dorm4You Arena
# Navigating to: Dorm4You Arena, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 183/1575: Mercat Suites
# Navigating to: Mercat Suites, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 184/1575: Blanq Marina Suites
# Navigating to: Blanq Marina Suites, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 185/1575: Reinapart Patacona Beach 46
# Navigating to: Reinapart Patacona Beach 46, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 186/1575: chalet, villa rodeada de naturaleza piscina a doce klm de Valencia y 7 del aeropuerto
# Navigating to: chalet, villa rodeada de naturaleza piscina a doce klm de Valencia y 7 del aeropuerto, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 187/1575: Dau Studios
# Navigating to: Dau Studios, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 188/1575: SingularStays Mar44
# Navigating to: SingularStays Mar44, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 189/1575: VLC HOST - Bellvis
# Navigating to: VLC HOST - Bellvis, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 190/1575: The Westin Valencia
# Navigating to: The Westin Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 191/1575: FLORIT FLATS - Ruzafa Attic with Private Terrace
# Navigating to: FLORIT FLATS - Ruzafa Attic with Private Terrace, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 192/1575: SingularStays Parque Central
# Navigating to: SingularStays Parque Central, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 193/1575: Casa Clarita
# Navigating to: Casa Clarita, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 194/1575: Palacios Rooms
# Navigating to: Palacios Rooms, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 195/1575: Slow Home Apartments
# Navigating to: Slow Home Apartments, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 196/1575: Catalonia Excelsior
# Navigating to: Catalonia Excelsior, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 197/1575: FLORIT FLATS - The Pitiusas Rooms
# Navigating to: FLORIT FLATS - The Pitiusas Rooms, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 198/1575: Hotel BESTPRICE Valencia
# Navigating to: Hotel BESTPRICE Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 199/1575: Concept Rooms
# Navigating to: Concept Rooms, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 200/1575: HQ Rooms Apartments San Vicente
# Navigating to: HQ Rooms Apartments San Vicente, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 201/1575: VLC HOST - Reina 168
# Navigating to: VLC HOST - Reina 168, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 202/1575: Hospederia del Pilar
# Navigating to: Hospederia del Pilar, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 203/1575: VLC HOST - Zapadores
# Navigating to: VLC HOST - Zapadores, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 204/1575: Sorolla Urban Suites
# Navigating to: Sorolla Urban Suites, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 205/1575: Hotel Medium Valencia
# Navigating to: Hotel Medium Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 206/1575: San Miguel, Luxury apartments.
# Navigating to: San Miguel, Luxury apartments., Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 207/1575: Las Arenas Balneario Resort
# Navigating to: Las Arenas Balneario Resort, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 208/1575: Melia Valencia
# Navigating to: Melia Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 209/1575: Hotel Pathos by Mimood Aparthotels
# Navigating to: Hotel Pathos by Mimood Aparthotels, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 210/1575: Senator Parque Central
# Navigating to: Senator Parque Central, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 211/1575: Kora Lluna
# Navigating to: Kora Lluna, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 212/1575: Exe Rey Don Jaime
# Navigating to: Exe Rey Don Jaime, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 213/1575: DWO Valencia
# Navigating to: DWO Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 214/1575: BET Apartments - Suites Puerto Valencia
# Navigating to: BET Apartments - Suites Puerto Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 215/1575: Hostal RR Feria by Beleret
# Navigating to: Hostal RR Feria by Beleret, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 216/1575: Apartamento Ciudad de Las Ciencias - Apartamento Ciudad de Les Arts
# Navigating to: Apartamento Ciudad de Las Ciencias - Apartamento Ciudad de Les Arts, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 217/1575: BET Apartments - Reig
# Navigating to: BET Apartments - Reig, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 218/1575: BET Apartments - Abastos
# Navigating to: BET Apartments - Abastos, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 219/1575: Macflats Valencia Puerto
# Navigating to: Macflats Valencia Puerto, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 220/1575: Reinapart Valencia Beach
# Navigating to: Reinapart Valencia Beach, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 221/1575: SOHO BY THE SEA Valencia
# Navigating to: SOHO BY THE SEA Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 222/1575: El Globo
# Navigating to: El Globo, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 223/1575: Hotel Miramar Valencia
# Navigating to: Hotel Miramar Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 224/1575: SingularStays Valencia Center
# Navigating to: SingularStays Valencia Center, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 225/1575: Living Valencia Apartments - Merced
# Navigating to: Living Valencia Apartments - Merced, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 226/1575: Hotel San Lorenzo Boutique Plaza
# Navigating to: Hotel San Lorenzo Boutique Plaza, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 227/1575: Osito Hub - Duque de Gaeta
# Navigating to: Osito Hub - Duque de Gaeta, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 228/1575: Hotel Arena Select
# Navigating to: Hotel Arena Select, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 229/1575: Valencia Luxury - Calma Beach Apartments
# Navigating to: Valencia Luxury - Calma Beach Apartments, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 230/1575: SH Suite Palace
# Navigating to: SH Suite Palace, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 231/1575: NH Collection Colón Valencia
# Navigating to: NH Collection Colón Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 232/1575: Travel Habitat Ayuntamiento
# Navigating to: Travel Habitat Ayuntamiento, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 233/1575: Maritime Apartamentos Cabañal
# Navigating to: Maritime Apartamentos Cabañal, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 234/1575: Ilunion Aqua 3
# Navigating to: Ilunion Aqua 3, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 235/1575: SH Ingles Boutique Hotel
# Navigating to: SH Ingles Boutique Hotel, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 236/1575: MH Apartments Central Valencia
# Navigating to: MH Apartments Central Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 237/1575: Design Apartment with swimming pool Ciudad de Ciencias
# Navigating to: Design Apartment with swimming pool Ciudad de Ciencias, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 238/1575: Valencia Luxury - Sea Port II
# Navigating to: Valencia Luxury - Sea Port II, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 239/1575: Palacio de Rojas by Moontels
# Navigating to: Palacio de Rojas by Moontels, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 240/1575: Amplio apartamento en Valencia Centro by Rent Me
# Navigating to: Amplio apartamento en Valencia Centro by Rent Me, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 241/1575: SingularStays Botanico29
# Navigating to: SingularStays Botanico29, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 242/1575: HQ Arena Hotel
# Navigating to: HQ Arena Hotel, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 243/1575: BYPILLOW Sinfonía
# Navigating to: BYPILLOW Sinfonía, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 244/1575: Luxury Beach Front Apartment with Pool
# Navigating to: Luxury Beach Front Apartment with Pool, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 245/1575: Apartamentos Plaza Picasso
# Navigating to: Apartamentos Plaza Picasso, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 246/1575: FLORIT FLATS - CENTER MODERN 1BR 2Bth TERRACE WI-FI AC
# Navigating to: FLORIT FLATS - CENTER MODERN 1BR 2Bth TERRACE WI-FI AC, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 247/1575: Hotel Kramer
# Navigating to: Hotel Kramer, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 248/1575: Ramirez Flats Valencia
# Navigating to: Ramirez Flats Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 249/1575: VLC HOST - Reina 168
# Navigating to: VLC HOST - Reina 168, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 250/1575: Hospederia del Pilar
# Navigating to: Hospederia del Pilar, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 251/1575: VLC HOST - Zapadores
# Navigating to: VLC HOST - Zapadores, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 252/1575: Sorolla Urban Suites
# Navigating to: Sorolla Urban Suites, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 253/1575: Hotel Medium Valencia
# Navigating to: Hotel Medium Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 254/1575: San Miguel, Luxury apartments.
# Navigating to: San Miguel, Luxury apartments., Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 255/1575: Las Arenas Balneario Resort
# Navigating to: Las Arenas Balneario Resort, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 256/1575: Melia Valencia
# Navigating to: Melia Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 257/1575: Hotel Pathos by Mimood Aparthotels
# Navigating to: Hotel Pathos by Mimood Aparthotels, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 258/1575: Senator Parque Central
# Navigating to: Senator Parque Central, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 259/1575: Kora Lluna
# Navigating to: Kora Lluna, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 260/1575: Exe Rey Don Jaime
# Navigating to: Exe Rey Don Jaime, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 261/1575: DWO Valencia
# Navigating to: DWO Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 262/1575: BET Apartments - Suites Puerto Valencia
# Navigating to: BET Apartments - Suites Puerto Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 263/1575: Hostal RR Feria by Beleret
# Navigating to: Hostal RR Feria by Beleret, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 264/1575: Apartamento Ciudad de Las Ciencias - Apartamento Ciudad de Les Arts
# Navigating to: Apartamento Ciudad de Las Ciencias - Apartamento Ciudad de Les Arts, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 265/1575: BET Apartments - Reig
# Navigating to: BET Apartments - Reig, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 266/1575: BET Apartments - Abastos
# Navigating to: BET Apartments - Abastos, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 267/1575: Macflats Valencia Puerto
# Navigating to: Macflats Valencia Puerto, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 268/1575: Reinapart Valencia Beach
# Navigating to: Reinapart Valencia Beach, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 269/1575: SOHO BY THE SEA Valencia
# Navigating to: SOHO BY THE SEA Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 270/1575: El Globo
# Navigating to: El Globo, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 271/1575: Hotel Miramar Valencia
# Navigating to: Hotel Miramar Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 272/1575: SingularStays Valencia Center
# Navigating to: SingularStays Valencia Center, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 273/1575: Living Valencia Apartments - Merced
# Navigating to: Living Valencia Apartments - Merced, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 274/1575: Lôla Suites by Concept Flats
# Navigating to: Lôla Suites by Concept Flats, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 275/1575: Reinapart Patacona Beach 36
# Navigating to: Reinapart Patacona Beach 36, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 276/1575: Casual Socarrat Valencia - Adults Only
# Navigating to: Casual Socarrat Valencia - Adults Only, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 277/1575: Lounge garden sea relax
# Navigating to: Lounge garden sea relax, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 278/1575: CAPSULE INN VALENCIA Hostel
# Navigating to: CAPSULE INN VALENCIA Hostel, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 279/1575: Lindala
# Navigating to: Lindala, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 280/1575: Melia Plaza Valencia
# Navigating to: Melia Plaza Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 281/1575: FLORIT FLATS - The Serreria Rooms
# Navigating to: FLORIT FLATS - The Serreria Rooms, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 282/1575: Casual Vintage Valencia
# Navigating to: Casual Vintage Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 283/1575: Valenciaflats Ciudad de las Ciencias
# Navigating to: Valenciaflats Ciudad de las Ciencias, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 284/1575: Visitacion Pool House
# Navigating to: Visitacion Pool House, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 285/1575: AC Hotel Valencia by Marriott
# Navigating to: AC Hotel Valencia by Marriott, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 286/1575: BONNIES Suites & Spa Valencia
# Navigating to: BONNIES Suites & Spa Valencia, Valencia (updated prices 2026)
# Description extracted
#
# ...
# Navigating to: DWO Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1498/1575: BET Apartments - Suites Puerto Valencia
# Navigating to: BET Apartments - Suites Puerto Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1499/1575: Hostal RR Feria by Beleret
# Navigating to: Hostal RR Feria by Beleret, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1500/1575: Apartamento Ciudad de Las Ciencias - Apartamento Ciudad de Les Arts
# Navigating to: Apartamento Ciudad de Las Ciencias - Apartamento Ciudad de Les Arts, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1501/1575: BET Apartments - Reig
# Navigating to: BET Apartments - Reig, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1502/1575: BET Apartments - Abastos
# Navigating to: BET Apartments - Abastos, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1503/1575: Macflats Valencia Puerto
# Navigating to: Macflats Valencia Puerto, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1504/1575: Reinapart Valencia Beach
# Navigating to: Reinapart Valencia Beach, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1505/1575: SOHO BY THE SEA Valencia
# Navigating to: SOHO BY THE SEA Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1506/1575: El Globo
# Navigating to: El Globo, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1507/1575: Hotel Miramar Valencia
# Navigating to: Hotel Miramar Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1508/1575: SingularStays Valencia Center
# Navigating to: SingularStays Valencia Center, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1509/1575: Living Valencia Apartments - Merced
# Navigating to: Living Valencia Apartments - Merced, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1510/1575: Buganvilla
# Navigating to: Buganvilla, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1511/1575: Comfortable Apartment in Mislata - 50 m² - Parking Included
# Navigating to: Comfortable Apartment in Mislata - 50 m² - Parking Included, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1512/1575: Spacious Apartment in Valencia with Sea View - 160 sqm
# Navigating to: Spacious Apartment in Valencia with Sea View - 160 sqm, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1513/1575: El Pino B & B, Chera
# Navigating to: El Pino B & B, Chera, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1514/1575: Habitación San Cayetano
# Navigating to: Habitación San Cayetano, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1515/1575: Canet De Berenguer, Playa Apto con 2 habitaciones
# Navigating to: Canet De Berenguer, Playa Apto con 2 habitaciones, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1516/1575: Playa de Canet, gran Terraza
# Navigating to: Playa de Canet, gran Terraza, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1517/1575: Era Deluxe Oasis 1 Near The Beach
# Navigating to: Era Deluxe Oasis 1 Near The Beach, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1518/1575: Cullera Valencia Escapada de ensueño
# Navigating to: Cullera Valencia Escapada de ensueño, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1519/1575: APARTAMENTO MARÍTIMO
# Navigating to: APARTAMENTO MARÍTIMO, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1520/1575: Piso perfecto
# Navigating to: Piso perfecto, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1521/1575: Ruzafa Apartment
# Navigating to: Ruzafa Apartment, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1522/1575: Casa del Portón - Housevanlive
# Navigating to: Casa del Portón - Housevanlive, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1523/1575: VLC Suite Yako
# Navigating to: VLC Suite Yako, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1524/1575: A45 ViviendaTurísticaValencia Mundo
# Navigating to: A45 ViviendaTurísticaValencia Mundo, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1525/1575: Catedral Reina Apartaments
# Navigating to: Catedral Reina Apartaments, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1526/1575: Xanquete
# Navigating to: Xanquete, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1527/1575: Villa near Valencia with Private Pool
# Navigating to: Villa near Valencia with Private Pool, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1528/1575: Barco para dormir sobre el Mar
# Navigating to: Barco para dormir sobre el Mar, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1529/1575: Cabanyal Rooms by VLC Host
# Navigating to: Cabanyal Rooms by VLC Host, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1530/1575: Artes 323
# Navigating to: Artes 323, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1531/1575: Blanq Gran vía
# Navigating to: Blanq Gran vía, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1532/1575: Balandra Flat
# Navigating to: Balandra Flat, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1533/1575: Residencia Universitaria Trinitarios
# Navigating to: Residencia Universitaria Trinitarios, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1534/1575: River Hostel
# Navigating to: River Hostel, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1535/1575: VLC HOST - Reina 168
# Navigating to: VLC HOST - Reina 168, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1536/1575: Hospederia del Pilar
# Navigating to: Hospederia del Pilar, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1537/1575: VLC HOST - Zapadores
# Navigating to: VLC HOST - Zapadores, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1538/1575: Sorolla Urban Suites
# Navigating to: Sorolla Urban Suites, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1539/1575: Hotel Medium Valencia
# Navigating to: Hotel Medium Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1540/1575: San Miguel, Luxury apartments.
# Navigating to: San Miguel, Luxury apartments., Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1541/1575: Las Arenas Balneario Resort
# Navigating to: Las Arenas Balneario Resort, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1542/1575: Melia Valencia
# Navigating to: Melia Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1543/1575: Hotel Pathos by Mimood Aparthotels
# Navigating to: Hotel Pathos by Mimood Aparthotels, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1544/1575: Senator Parque Central
# Navigating to: Senator Parque Central, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1545/1575: Kora Lluna
# Navigating to: Kora Lluna, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1546/1575: Exe Rey Don Jaime
# Navigating to: Exe Rey Don Jaime, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1547/1575: DWO Valencia
# Navigating to: DWO Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1548/1575: BET Apartments - Suites Puerto Valencia
# Navigating to: BET Apartments - Suites Puerto Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1549/1575: Hostal RR Feria by Beleret
# Navigating to: Hostal RR Feria by Beleret, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1550/1575: Apartamento Ciudad de Las Ciencias - Apartamento Ciudad de Les Arts
# Navigating to: Apartamento Ciudad de Las Ciencias - Apartamento Ciudad de Les Arts, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1551/1575: BET Apartments - Reig
# Navigating to: BET Apartments - Reig, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1552/1575: BET Apartments - Abastos
# Navigating to: BET Apartments - Abastos, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1553/1575: Macflats Valencia Puerto
# Navigating to: Macflats Valencia Puerto, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1554/1575: Reinapart Valencia Beach
# Navigating to: Reinapart Valencia Beach, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1555/1575: SOHO BY THE SEA Valencia
# Navigating to: SOHO BY THE SEA Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1556/1575: El Globo
# Navigating to: El Globo, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1557/1575: Hotel Miramar Valencia
# Navigating to: Hotel Miramar Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1558/1575: SingularStays Valencia Center
# Navigating to: SingularStays Valencia Center, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1559/1575: Living Valencia Apartments - Merced
# Navigating to: Living Valencia Apartments - Merced, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1560/1575: Livensa Living Studios Valencia Marina Real Hotel-Apartamento
# Navigating to: Livensa Living Studios Valencia Marina Real Hotel-Apartamento, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1561/1575: Camila Hostel Valencia
# Navigating to: Camila Hostel Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1562/1575: SOM Hostel Valencia
# Navigating to: SOM Hostel Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1563/1575: U-nit Hostel Central Park
# Navigating to: U-nit Hostel Central Park, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1564/1575: Colo Colo Hostel Valencia - Single Private Beds
# Navigating to: Colo Colo Hostel Valencia - Single Private Beds, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1565/1575: Red Nest Hostel
# Navigating to: Red Nest Hostel, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1566/1575: Urban Youth Hostel
# Navigating to: Urban Youth Hostel, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1567/1575: Purple Nest Hostel
# Navigating to: Purple Nest Hostel, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1568/1575: Home Youth Hostel by Feetup Hostels
# Navigating to: Home Youth Hostel by Feetup Hostels, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1569/1575: Beach & Arts Hostel Valencia
# Navigating to: Beach & Arts Hostel Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1570/1575: UP Hostel Valencia
# Navigating to: UP Hostel Valencia, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1571/1575: Cantagua Hostel
# Navigating to: Cantagua Hostel, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1572/1575: Reina 107 Beach Boutique
# Navigating to: Reina 107 Beach Boutique, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1573/1575: The POD Suite Hostel Village
# Navigating to: The POD Suite Hostel Village, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1574/1575: The POD Suite Hostel Blasco
# Navigating to: The POD Suite Hostel Blasco, Valencia (updated prices 2026)
# Description extracted
#
# Extracting Description for 1575/1575: Gypsy Budget Room Shared Flat
# Navigating to: Gypsy Budget Room Shared Flat, Valencia (updated prices 2026)
# Description extracted
#
# ✅ Completed extracting descriptions for 1575 hotels
# ✅ Saved: data/Valencia/2026-03-13.csv
# Scraping 2026-03-14 → 2026-03-21
#
# ✅ Browser opened!
# ✅ Navigated to Booking.com search results
# Page title: Booking.com | Official site | The best hotels, flights, car rentals & accommodations
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[25], line 20
#      17 print(f"Scraping {start_date_str} → {end_date_str}\n")
#      19 # Open website
# ---> 20 driver = open_website(website_url=booking_url)
#      22 # Search for Valencia with the given dates
#      23 driver = search(driver=driver, city=city, start_date=start_date_str, end_date=end_date_str)
#
# Cell In[2], line 27, in open_website(website_url, headless_bool)
#      24 driver.set_window_size(1400, 900)
#      26 # accept cookies
# ---> 27 accept_button = driver.find_element(By.ID, "onetrust-accept-btn-handler")
#      28 accept_button.click()  # Example: Accept cookies button
#      29 time.sleep(5)  # Wait for page to load
#
# File ~/bse/text_mining/scrapping/.venv/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py:802, in WebDriver.find_element(self, by, value)
#     799         raise NoSuchElementException(f"Cannot locate relative element with: {by.root}")
#     800     return elements[0]
# --> 802 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~/bse/text_mining/scrapping/.venv/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py:432, in WebDriver.execute(self, driver_command, params)
#     429 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     431 if response:
# --> 432     self.error_handler.check_response(response)
#     433     response["value"] = self._unwrap_value(response.get("value", None))
#     434     return response
#
# File ~/bse/text_mining/scrapping/.venv/lib/python3.12/site-packages/selenium/webdriver/remote/errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 232 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="onetrust-accept-btn-handler"]"}
#   (Session info: chrome=144.0.7559.59); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# #0 0x58f9e0205c3a <unknown>
# #1 0x58f9dfc1f969 <unknown>
# #2 0x58f9dfc74ead <unknown>
# #3 0x58f9dfc750f1 <unknown>
# #4 0x58f9dfcc07e4 <unknown>
# #5 0x58f9dfcbda20 <unknown>
# #6 0x58f9dfc66be2 <unknown>
# #7 0x58f9dfc67991 <unknown>
# #8 0x58f9e01cba99 <unknown>
# #9 0x58f9e01ce9b1 <unknown>
# #10 0x58f9e01b80a9 <unknown>
# #11 0x58f9e01cf56e <unknown>
# #12 0x58f9e019e5e0 <unknown>
# #13 0x58f9e01f3358 <unknown>
# #14 0x58f9e01f3528 <unknown>
# #15 0x58f9e0204fa8 <unknown>
# #16 0x76c341c9caa4 <unknown>
# #17 0x76c341d29c6c <unknown>

# %% [markdown]
# ## Consolidate Valencia

# %%
folder = "data/Valencia"

all_dfs = []

# Combine different date csvs
for filename in os.listdir(folder):
    if filename.endswith(".csv"):
        
        # Extract date from filename 
        date_str = filename.replace(".csv", "")
        
        # Load CSV
        file_path = os.path.join(folder, filename)
        df = pd.read_csv(file_path)
        
        # Add date column
        df["date"] = date_str
        
        # Collect
        all_dfs.append(df)

# Combine everything
df = pd.concat(all_dfs, ignore_index=True)

# %%
# Drop duplicates that appear because the link changes when Load More button is clicked
df = df.drop_duplicates(subset=["date", "hotel", "price"])

# handle the price symbols
df['price'] = df['price'].astype(str)
df['price'] = df['price'].str.replace("€ ", "", regex=False)
df['price'] = df['price'].str.replace(",", "", regex=False)
df['price'] = df['price'].str.replace(" ", "", regex=False)
df['price'] = pd.to_numeric(df['price'], errors='coerce')

# Check for nas
print(f"Contains {df.isna().sum()} values \n")

# Check the number of observations per date
print(df['date'].value_counts())

# Assign city variable
df['city'] = 'Valencia'

# Assign treatCity variable 
df['treatCity'] = np.where(df['city'] == "Valencia", 1, 0)

# Assign treatPeriod variable
df['treatPeriod'] = np.where(df['date'].isin(["2026-03-14", "2026-03-15", "2026-03-16", "2026-03-17", "2026-03-18", "2026-03-19"]), 1, 0)

# Reorder columns as instructed
df = df[['city', 'hotel', 'date', 'price', 'treatCity', 'treatPeriod', 'text', 'link']]

# Drop the link variable
df = df.drop(columns = ['link'])
# Out:
# Contains city           0
# hotel          0
# date           0
# price          0
# treatCity      0
# treatPeriod    0
# text           2
# link           0
# dtype: int64 values
#
# date
# 2026-03-07    926
# 2026-04-01    919
# 2026-03-26    910
# 2026-03-01    908
# 2026-03-21    896
# 2026-03-16    805
# 2026-03-17    803
# 2026-03-15    778
# 2026-03-13    775
# Name: count, dtype: int64

# %%
val = df
val
# Out:
#            city                                              hotel  \
# 0      Valencia               amazing cozy apartment super central
# 1      Valencia                 Hotel Pathos by Mimood Aparthotels
# 2      Valencia                                Main Lofts Valencia
# 3      Valencia                          Arena Legacy Modern Suits
# 4      Valencia                            Apartamento Río Turia B
# ...         ...                                                ...
# 13031  Valencia                 Habitación en el centro con balcón
# 13032  Valencia              Urban apartment 4 BAJO - Housevanlive
# 13033  Valencia                  Era Deluxe Near The Beach City Of
# 13034  Valencia  Resort & Suites Ciudad de las Ciencias By VALE...
# 13035  Valencia                                    Ruzafa Tropical
#
#              date  price  treatCity  treatPeriod  \
# 0      2026-03-07   1041          1            0
# 1      2026-03-07   1176          1            0
# 2      2026-03-07   1747          1            0
# 3      2026-03-07   1301          1            0
# 4      2026-03-07   1132          1            0
# ...           ...    ...        ...          ...
# 13031  2026-04-01    700          1            0
# 13032  2026-04-01   2310          1            0
# 13033  2026-04-01   1693          1            0
# 13034  2026-04-01   3665          1            0
# 13035  2026-04-01   1554          1            0
#
#                                                     text
# 0      Modern Comforts: The apartment offers free WiF...
# 1      Hotel Pathos by Mimood Aparthotels – Comfort a...
# 2      Modern Comforts: Main Lofts Valencia in Valenc...
# 3      Modern Comfort: Arena Legacy Modern Suits in V...
# 4      Modern Comforts: Apartamento Río Turia B in Va...
# ...                                                  ...
# 13031  Comfortable Accommodations: Habitación en el c...
# 13032  Spacious and Pet-Friendly: Urban apartment 4 B...
# 13033  Comfortable Living: Era Deluxe Near The Beach ...
# 13034  Prime Location: Resort & Suites Ciudad de las ...
# 13035  Comfortable Living: Ruzafa Tropical in Valenci...
#
# [7720 rows x 7 columns]

# %%
# Compute average price per date
avg_price = df.groupby("date")["price"].mean()

# Plot
plt.figure(figsize=(12, 6))
avg_price.plot(kind="line", marker="o")

plt.title("Average Price per Date")
plt.xlabel("Date")
plt.ylabel("Average Price")
plt.xticks(rotation=45)
plt.grid(True)

plt.show()

# %% [markdown]
# ## Consolidate Alicante

# %%
df = pd.read_csv("data/Alicante/booking_alicante.csv")

# %%
# rename the date columns
df = df.rename(columns={"checkin_date" : "date"})

# Drop duplicates that appear because the link changes when Load More button is clicked
df = df.drop_duplicates(subset=["date", "hotel", "price"])

# Check for nas
print(f"Contains {df.isna().sum()} values \n")

# Check the number of observations per date
print(df['date'].value_counts())

# Assign city variable
df['city'] = 'Alicante'

# Assign treatCity variable 
df['treatCity'] = np.where(df['city'] == "Valencia", 1, 0)

# Assign treatPeriod variable
df['treatPeriod'] = np.where(df['date'].isin(["2026-03-14", "2026-03-15", "2026-03-16", "2026-03-17", "2026-03-18", "2026-03-19"]), 1, 0)

# Reorder columns as instructed
df = df[['city', 'hotel', 'date', 'price', 'treatCity', 'treatPeriod', 'text', 'link']]

# Drop the link variable
df = df.drop(columns = ['link'])
# Out:
# Contains hotel    0
# price    0
# date     0
# city     0
# text     3
# link     0
# dtype: int64 values
#
# date
# 2026-03-17    887
# 2026-03-19    882
# 2026-03-13    881
# 2026-03-18    879
# 2026-03-14    876
# 2026-03-16    874
# 2026-03-15    842
# 2026-03-01    808
# 2026-03-12    780
# 2026-02-27    755
# 2026-02-28    745
# 2026-03-28    691
# 2026-03-02     50
# Name: count, dtype: int64

# %%
ali = df
df
# Out:
#           city                                              hotel        date  \
# 0     Alicante                       La Luna Apartment by the Sea  2026-02-27
# 1     Alicante                             Hotel Albahia Alicante  2026-02-27
# 2     Alicante                       Monumental Mercado by Manlia  2026-02-27
# 3     Alicante                                Estudiotel Alicante  2026-02-27
# 4     Alicante                                   Gerona by Manlia  2026-02-27
# ...        ...                                                ...         ...
# 9945  Alicante             VAD HOSTEL ALICANTE - Albergue Juvenil  2026-03-19
# 9946  Alicante                    Chameleon Youth Hostel Alicante  2026-03-19
# 9947  Alicante  HOSTEL Pepper-Gold - PORT AREA -FREE TOWELS - ...  2026-03-19
# 9948  Alicante                               Hola Hostel Alicante  2026-03-19
# 9949  Alicante                                 Rooms in Apartment  2026-03-19
#
#        price  treatCity  treatPeriod  \
# 0     1365.0          0            0
# 1      350.0          0            0
# 2      834.0          0            0
# 3      482.0          0            0
# 4      831.0          0            0
# ...      ...        ...          ...
# 9945   336.0          0            1
# 9946   317.0          0            1
# 9947   420.0          0            1
# 9948   907.0          0            1
# 9949   787.0          0            1
#
#                                                    text
# 0     Spacious Accommodations: La Luna Apartment by ...
# 1     Hotel Albahia Alicante is located 8 minutes' w...
# 2     Modern Comforts: Monumental Mercado by Manlia ...
# 3     Estudiotel Alicante's spacious rooms offer fre...
# 4     Modern Comforts: Gerona by Manlia in Alicante ...
# ...                                                 ...
# 9945  Comfortable Accommodations: VAD HOSTEL ALICANT...
# 9946  Comfortable Accommodations: Chameleon Youth Ho...
# 9947  Comfortable Accommodations: HOSTEL Pepper-Gold...
# 9948  Comfortable Accommodations: Hola Hostel Alican...
# 9949  Comfortable Accommodations: Rooms in Apartment...
#
# [9950 rows x 7 columns]

# %%
# Compute average price per date
avg_price = df.groupby("date")["price"].mean()

# Plot
plt.figure(figsize=(12, 6))
avg_price.plot(kind="line", marker="o")

plt.title("Average Price per Date")
plt.xlabel("Date")
plt.ylabel("Average Price")
plt.xticks(rotation=45)
plt.grid(True)

plt.show()

# %% [markdown]
# ## Consolidate the final table

# %%
# aggregate Valencia and Alicant
df = pd.concat([val, ali], ignore_index=True)

# Check for the common dates
cities = df['city'].unique()
dates_city1 = set(df[df['city'] == cities[0]]['date'])
dates_city2 = set(df[df['city'] == cities[1]]['date'])
common_dates = dates_city1.intersection(dates_city2)
common_dates = list(common_dates)
common_dates
# Out:
# ['2026-03-13', '2026-03-17', '2026-03-01', '2026-03-16', '2026-03-15']

# %%
df = df[df['date'].isin(common_dates)]
df
# Out:
#            city                                              hotel  \
# 926    Valencia                               VLC HOST - Reina 168
# 927    Valencia                               Hospederia del Pilar
# 928    Valencia                               VLC HOST - Zapadores
# 929    Valencia                               Sorolla Urban Suites
# 930    Valencia                              Hotel Medium Valencia
# ...         ...                                                ...
# 15904  Alicante             VAD HOSTEL ALICANTE - Albergue Juvenil
# 15905  Alicante                    Chameleon Youth Hostel Alicante
# 15906  Alicante  HOSTEL Pepper-Gold - PORT AREA -FREE TOWELS - ...
# 15907  Alicante                               Hola Hostel Alicante
# 15908  Alicante                                 Rooms in Apartment
#
#              date   price  treatCity  treatPeriod  \
# 926    2026-03-13  1279.0          1            0
# 927    2026-03-13   864.0          1            0
# 928    2026-03-13  1585.0          1            0
# 929    2026-03-13  1397.0          1            0
# 930    2026-03-13  1404.0          1            0
# ...           ...     ...        ...          ...
# 15904  2026-03-17   336.0          0            1
# 15905  2026-03-17   317.0          0            1
# 15906  2026-03-17   420.0          0            1
# 15907  2026-03-17   851.0          0            1
# 15908  2026-03-17   787.0          0            1
#
#                                                     text
# 926    Comfortable Accommodations: VLC HOST - Reina 1...
# 927    Open since 1886, the Hospederia del Pilar is a...
# 928    Modern Comforts: VLC HOST - Zapadores in Valen...
# 929    Comfortable Accommodations: Sorolla Urban Suit...
# 930    Comfortable Accommodations: Hotel Medium Valen...
# ...                                                  ...
# 15904  Comfortable Accommodations: VAD HOSTEL ALICANT...
# 15905  Comfortable Accommodations: Chameleon Youth Ho...
# 15906  Comfortable Accommodations: HOSTEL Pepper-Gold...
# 15907  Comfortable Accommodations: Hola Hostel Alican...
# 15908  Comfortable Accommodations: Rooms in Apartment...
#
# [8361 rows x 7 columns]

# %%
# Count rows per (city, date)
counts = df.groupby(["city", "date"]).size().reset_index(name="n")

# Pivot so each city becomes its own line/column
pivoted = counts.pivot(index="date", columns="city", values="n")

# Plot
plt.figure(figsize=(12, 6))
pivoted.plot(kind="line", marker="o")

plt.title("Number of Observations per City and Date")
plt.xlabel("Date")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Average price per (city, date)
avg = (
    df.groupby(["city", "date"])["price"]
      .mean()
      .reset_index()
)

# Pivot so each city becomes its own series
pivoted = avg.pivot(index="date", columns="city", values="price")

# Plot
plt.figure(figsize=(12, 6))
pivoted.plot(kind="line", marker="o")

plt.title("Average Price per City and Date")
plt.xlabel("Date")
plt.ylabel("Average Price")
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()
